# %%
import sys
sys.path.insert(0, "../src/")
from eternitree import *

# %%
for p in SetPartitions():
    if p.size == 4:
        break
    print(p)
# Out:
# Set partition {0: [1]}
# Set partition {0: [1, 2]}
# Set partition {0: [1], 1: [2]}
# Set partition {0: [1, 2, 3]}
# Set partition {0: [1, 2], 1: [3]}
# Set partition {0: [1, 3], 1: [2]}
# Set partition {0: [1], 1: [2, 3]}
# Set partition {0: [1], 1: [2], 2: [3]}

# %%
SetPartition([[1,3],[2]]) in SetPartitions()
# Out:
# True

# %%
DoubleRecursiveTrees()
# Out:
# Double recursive trees

# %%
for p in IP:
    if p.size == 6:
        break
    print(p)
# Out:
# Partition [1]
# Partition [1, 1]
# Partition [2]
# Partition [1, 1, 1]
# Partition [2, 1]
# Partition [3]
# Partition [1, 1, 1, 1]
# Partition [2, 1, 1]
# Partition [3, 1]
# Partition [2, 2]
# Partition [4]
# Partition [1, 1, 1, 1, 1]
# Partition [2, 1, 1, 1]
# Partition [3, 1, 1]
# Partition [2, 2, 1]
# Partition [4, 1]
# Partition [3, 2]
# Partition [5]

# %%
type(P)
# Out:
# eternitree.abstraction.partition.IntegerPartition
