# %%
import sys
sys.path.insert(0, "../src/")
from eternitree import *

# %%
SP = SetPartition([[1,4,6], [5,7], [2]])
SP
# Out:
# Set partition {0: [1, 4, 6], 1: [2], 2: [5, 7]}

# %%
SP4 = SetPartitions([1,2,3,6])

# %%
list(SP4)
# Out:
# [Set partition {0: [1, 2, 3, 6]},
#  Set partition {0: [1, 2, 3], 1: [6]},
#  Set partition {0: [1, 2, 6], 1: [3]},
#  Set partition {0: [1, 2], 1: [3, 6]},
#  Set partition {0: [1, 2], 1: [3], 2: [6]},
#  Set partition {0: [1, 3, 6], 1: [2]},
#  Set partition {0: [1, 3], 1: [2, 6]},
#  Set partition {0: [1, 3], 1: [2], 2: [6]},
#  Set partition {0: [1, 6], 1: [2, 3]},
#  Set partition {0: [1], 1: [2, 3, 6]},
#  Set partition {0: [1], 1: [2, 3], 2: [6]},
#  Set partition {0: [1, 6], 1: [2], 2: [3]},
#  Set partition {0: [1], 1: [2, 6], 2: [3]},
#  Set partition {0: [1], 1: [2], 2: [3, 6]},
#  Set partition {0: [1], 1: [2], 2: [3], 3: [6]}]

# %%
bell_number(5)
# Out:
# 52

# %%
list(range(9,-1,-1))
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]
