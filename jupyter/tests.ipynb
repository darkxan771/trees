# %%
import sys
sys.path.insert(0, "../")
from tests import *

# %%
test_random()
# Out:
# Random uniform rooted tree
#  Random uniform recursive tree
#  Random Plancherel recursive tree
#  Random uniform partition
#  Random Plancherel partition
#  Done !
